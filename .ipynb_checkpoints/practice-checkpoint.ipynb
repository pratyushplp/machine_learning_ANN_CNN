# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import cv2
import glob
import scipy.misc
import pandas as pd
import random


#must for gpu
os.environ["CUDA_VISIBLE_DEVICES"] = '0' #use GPU with ID=0
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.5 # maximun alloc gpu50% of MEM
config.gpu_options.allow_growth = True #allocate dynamically
sess = tf.Session(config = config)

# load own handwriting
dataset = []

# load the png image data

for image_file_name in glob.glob('C:/Users/Pratyus Pradhan/Downloads/*.jpg'):
   

    #img_array = scipy.misc.imread(image_file_name, flatten=True)#Read an image from a file as an array
    img_array=cv2.imread(image_file_name,cv2.IMREAD_GRAYSCALE)
    plt.imshow(img_array, cmap="gray")
    plt.show()
    print(img_array.shape)
    break
# Out:
# (419, 419)

# %%
img_size=36
#temp_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
temp_array= cv2.resize(img_array,(img_size,img_size))
plt.imshow(temp_array,cmap='gray')
plt.show()
cv2.imwrite('test_ek.jpg',img_array)
# Out:
# False

# %%
cv2.imwrite('D:\ML\plp.jpg',temp_array)
# Out:
# True

# %%
import time
dense_layers=[0,1,2]
layer_sizes=[64,128,164]
conv_layers=[2,3,4]
for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME="{}-conv-{}-nodes-{}-dense-{}".format(conv_layer,layer_size,dense_layer,int(time.time()))
            print(NAME)
# Out:
# 2-conv-64-nodes-0-dense-1535972385
# 3-conv-64-nodes-0-dense-1535972385
# 4-conv-64-nodes-0-dense-1535972385
# 2-conv-128-nodes-0-dense-1535972385
# 3-conv-128-nodes-0-dense-1535972385
# 4-conv-128-nodes-0-dense-1535972385
# 2-conv-164-nodes-0-dense-1535972385
# 3-conv-164-nodes-0-dense-1535972385
# 4-conv-164-nodes-0-dense-1535972385
# 2-conv-64-nodes-1-dense-1535972385
# 3-conv-64-nodes-1-dense-1535972385
# 4-conv-64-nodes-1-dense-1535972385
# 2-conv-128-nodes-1-dense-1535972385
# 3-conv-128-nodes-1-dense-1535972385
# 4-conv-128-nodes-1-dense-1535972385
# 2-conv-164-nodes-1-dense-1535972385
# 3-conv-164-nodes-1-dense-1535972385
# 4-conv-164-nodes-1-dense-1535972385
# 2-conv-64-nodes-2-dense-1535972385
# 3-conv-64-nodes-2-dense-1535972385
# 4-conv-64-nodes-2-dense-1535972385
# 2-conv-128-nodes-2-dense-1535972385
# 3-conv-128-nodes-2-dense-1535972385
# 4-conv-128-nodes-2-dense-1535972385
# 2-conv-164-nodes-2-dense-1535972385
# 3-conv-164-nodes-2-dense-1535972385
# ...
